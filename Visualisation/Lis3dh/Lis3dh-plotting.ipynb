# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
df = pd.read_csv("../../Data/lis3dh/test_7.csv", names=['Timestamp','X_axis','Y_axis','Z_axis', 'TBD'])
df.dtypes
# Out:
# Timestamp      int64
# X_axis       float64
# Y_axis       float64
# Z_axis       float64
# TBD          float64
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of      Timestamp  X_axis  Y_axis  Z_axis  TBD
# 0        14757    0.06    0.06    1.06  NaN
# 1        15259    0.06    0.06    1.05  NaN
# 2        15761    0.06    0.06    1.06  NaN
# 3        16263    0.06    0.06    1.05  NaN
# 4        16765    0.06    0.06    1.05  NaN
# ..         ...     ...     ...     ...  ...
# 103      66463    0.06    0.06    1.05  NaN
# 104      66965    0.06    0.06    1.05  NaN
# 105      67467    0.06    0.06    1.05  NaN
# 106      67969    0.06    0.06    1.06  NaN
# 107      68471    0.06    0.06    1.05  NaN
#
# [108 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['Timestamp', 'X_axis', 'Y_axis', 'Z_axis', 'TBD'], dtype='object')

# %%
df.drop("TBD", axis=1)
# Out:
#      Timestamp  X_axis  Y_axis  Z_axis
# 0        14757    0.06    0.06    1.06
# 1        15259    0.06    0.06    1.05
# 2        15761    0.06    0.06    1.06
# 3        16263    0.06    0.06    1.05
# 4        16765    0.06    0.06    1.05
# ..         ...     ...     ...     ...
# 103      66463    0.06    0.06    1.05
# 104      66965    0.06    0.06    1.05
# 105      67467    0.06    0.06    1.05
# 106      67969    0.06    0.06    1.06
# 107      68471    0.06    0.06    1.05
#
# [108 rows x 4 columns]

# %%
sns.lineplot(data=df, x="Timestamp", y="X_axis")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='X_axis'>

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(df["Timestamp"], df["X_axis"])
ax.plot(df["Timestamp"], df["Y_axis"])
ax.plot(df["Timestamp"], df["Z_axis"])
